# %%
from FFNN import FFNN
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state

# %%
t0 = time.time()
train_samples = 50000

# %%
X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)

# %%
random_state = check_random_state(0)
permutation = random_state.permutation(X.shape[0])
X = X[permutation]
y = y[permutation]
X = X.reshape((X.shape[0], -1))

# %%
print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=train_samples, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = FFNN(
    layers=[X_train.shape[1], 20, 20, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model.fit(X_train, y_train, X_test, y_test)
y_pred = model.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [03:23<00:00, 20.31s/epoch, Train Loss: 0.0000 | Val Loss: 31.0874]
# Training completed.
# Test score with FFNN: 0.0999

# %%
model.save("models/model.pkl")

# %%
model2 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model2.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model2.fit(X_train, y_train, X_test, y_test)
y_pred = model2.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:43<00:00, 16.31s/epoch, Train Loss: 0.0000 | Val Loss: 29.2223]
# Training completed.
# Test score with FFNN: 0.1539

# %%
model2.save("models/model2.pkl")

# %%
model3 = FFNN(
    layers=[X_train.shape[1], 10, 10, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model3.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model3.fit(X_train, y_train, X_test, y_test)
y_pred = model3.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:03<00:00, 12.39s/epoch, Train Loss: 0.0000 | Val Loss: 30.2313]
# Training completed.
# Test score with FFNN: 0.1247

# %%
model3.save("models/model3.pkl")

# %%
model4 = FFNN(
    layers=[X_train.shape[1], 15, 15, 15, 10],
    activation_functions=["relu", "relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model4.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model4.fit(X_train, y_train, X_test, y_test)
y_pred = model4.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [03:32<00:00, 21.27s/epoch, Train Loss: 0.0000 | Val Loss: 30.2584]
# Training completed.
# Test score with FFNN: 0.1239

# %%
model4.save("models/model4.pkl")

# %%
model5 = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model5.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model5.fit(X_train, y_train, X_test, y_test)
y_pred = model5.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [01:54<00:00, 11.49s/epoch, Train Loss: 0.0000 | Val Loss: 29.4443]
# Training completed.
# Test score with FFNN: 0.1475

# %%
model5.save("models/model5.pkl")

# %%
sigmoid = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["sigmoid", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
sigmoid.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

sigmoid.fit(X_train, y_train, X_test, y_test)
y_pred = sigmoid.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [01:51<00:00, 11.14s/epoch, Train Loss: 0.0000 | Val Loss: 30.5273]
# Training completed.
# Test score with FFNN: 0.1161

# %%
sigmoid.save("models/sigmoid.pkl")

# %%
linear = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["linear", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
linear.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

linear.fit(X_train, y_train, X_test, y_test)
y_pred = linear.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Training:   0%|          | 0/10 [00:00<?, ?epoch/s]/Users/justin/Documents/ITB/Semester 6/Pembelajaran Mesin/Tugas Besar/Tubes 1/Tugas-Machine-Learning-1/src/FFNN.py:29: RuntimeWarning: overflow encountered in exp
#   self.output = 1 / (1 + np.exp(-z))
# Epoch 10: 100%|██████████| 10/10 [01:49<00:00, 10.93s/epoch, Train Loss: 15.5162 | Val Loss: 31.5216]
# Training completed.
# Test score with FFNN: 0.0874

# %%
linear.save("models/linear.pkl")

# %%
tanh = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["tanh", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
tanh.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

tanh.fit(X_train, y_train, X_test, y_test)
y_pred = tanh.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [01:54<00:00, 11.40s/epoch, Train Loss: 14.4538 | Val Loss: 31.4451]
# Training completed.
# Test score with FFNN: 0.0896

# %%
tanh.save("models/tanh.pkl")

# %%
model6 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.01, epoch=10, verbose=1, 
    batch_size=1
)
model6.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model6.fit(X_train, y_train, X_test, y_test)
y_pred = model6.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:42<00:00, 16.26s/epoch, Train Loss: 0.0000 | Val Loss: 29.2469]
# Training completed.
# Test score with FFNN: 0.1532

# %%
model6.save("models/model6.pkl")

# %%
model7 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.001, epoch=10, verbose=1, 
    batch_size=1
)
model7.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model7.fit(X_train, y_train, X_test, y_test)
y_pred = model7.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:44<00:00, 16.48s/epoch, Train Loss: 0.0000 | Val Loss: 29.2469]
# Training completed.
# Test score with FFNN: 0.1532

# %%
model7.save("models/model7.pkl")

# %%
model8 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.0001, epoch=10, verbose=1, 
    batch_size=1
)
model8.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model8.fit(X_train, y_train, X_test, y_test)
y_pred = model8.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:43<00:00, 16.35s/epoch, Train Loss: 0.0004 | Val Loss: 29.2519]
# Training completed.
# Test score with FFNN: 0.1531

# %%
model8.save("models/model8.pkl")

# %%
model8batch = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.01, epoch=10, verbose=1, 
    batch_size=200
)
model8batch.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model8batch.fit(X_train, y_train, X_test, y_test)
y_pred = model8batch.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [01:15<00:00,  7.54s/epoch, Train Loss: 0.0008 | Val Loss: 29.2469]
# Training completed.
# Test score with FFNN: 0.1532

# %%
model8batch.save("models/model8batch.pkl")

# %%
model_zero = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_zero.weight_initializer(weight_initializer="zero")

model_zero.fit(X_train, y_train, X_test, y_test)
y_pred = model_zero.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:46<00:00, 16.65s/epoch, Train Loss: 0.0000 | Val Loss: 31.0800]
# Training completed.
# Test score with FFNN: 0.1001

# %%
model_zero.save("models/model_zero.pkl")

# %%
model_uniform = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_uniform.weight_initializer(weight_initializer="uniform")
model_uniform.fit(X_train, y_train, X_test, y_test)
y_pred = model_uniform.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:46<00:00, 16.61s/epoch, Train Loss: 3.3447 | Val Loss: 31.0800]
# Training completed.
# Test score with FFNN: 0.1001

# %%
model_uniform.save("models/model_uniform.pkl")

# %%
model_L1 = FFNN(
    layers=[X_train.shape[1], 20, 20, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1, l1_lambda=0.001
)
model_L1.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model_L1.fit(X_train, y_train, X_test, y_test)
y_pred = model_L1.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [03:48<00:00, 22.83s/epoch, Train Loss: 0.0000 | Val Loss: 30.7000]
# Training completed.
# Test score with FFNN: 0.1111

# %%
model_L1.save("models/model_L1.pkl")

# %%
model_L2 = FFNN(
    layers=[X_train.shape[1], 20, 20, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1, l2_lambda=0.001
)
model_L2.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model_L2.fit(X_train, y_train, X_test, y_test)
y_pred = model_L2.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 10: 100%|██████████| 10/10 [03:23<00:00, 20.37s/epoch, Train Loss: 0.0000 | Val Loss: 31.1786]
# Training completed.
# Test score with FFNN: 0.0973

# %%
model_L2.save("models/model_L2.pkl")

# %%
model_sklearn_compare = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_sklearn_compare.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model_sklearn_compare.fit(X_train, y_train, X_test, y_test)
y_pred = model_sklearn_compare.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_sklearn_compare.save("models/model_sklearn_compare.pkl")
# Out:
# Epoch 10: 100%|██████████| 10/10 [02:43<00:00, 16.39s/epoch, Train Loss: 0.0000 | Val Loss: 29.2223]
# Training completed.
# Test score with FFNN: 0.1539

# %%
model_sklearn = MLPClassifier(
    hidden_layer_sizes=(15, 15),  
    activation='relu', 
    learning_rate_init=0.1,  
    max_iter=10, 
    batch_size=1, 
    random_state=42,
)
model_sklearn.fit(X_train, y_train)
y_pred = model_sklearn.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with sklearn MLPClassifier: %.4f" % score)
# Out:
# Test score with sklearn MLPClassifier: 0.1001
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import pickle


with open("models/model_sklearn.pkl", "wb") as f:
    pickle.dump(model_sklearn, f)
