# %%
from FFNN import FFNN
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state

# %%
t0 = time.time()
train_samples = 50000

# %%
X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)

# %%
random_state = check_random_state(0)
permutation = random_state.permutation(X.shape[0])
X = X[permutation]
y = y[permutation]
X = X.reshape((X.shape[0], -1))

# %%
print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=train_samples, test_size=0.2
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = FFNN(
    layers=[X_train.shape[1], 20, 20, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model.fit(X_train, y_train, X_test, y_test)
y_pred = model.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model.save("model.pkl")

# %%
model2 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model2.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model2.fit(X_train, y_train, X_test, y_test)
y_pred = model2.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model2.save("model2.pkl")

# %%
model3 = FFNN(
    layers=[X_train.shape[1], 10, 10, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model3.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model3.fit(X_train, y_train, X_test, y_test)
y_pred = model3.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model3.save("model3.pkl")

# %%
model4 = FFNN(
    layers=[X_train.shape[1], 15, 15, 15, 10],
    activation_functions=["relu", "relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model4.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model4.fit(X_train, y_train, X_test, y_test)
y_pred = model4.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 1, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 2, Training Loss: 3.4756153510784327e-15
# Validation Loss: 30.42372789300275
# Epoch 3, Training Loss: 3.4756153510784327e-15
# Validation Loss: 30.42372789300275
# Epoch 4, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 5, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 6, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 7, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 8, Training Loss: 3.475615351078433e-15
# Validation Loss: 30.42372789300275
# Epoch 9, Training Loss: 3.4756153510784327e-15
# Validation Loss: 30.42372789300275
# Epoch 10, Training Loss: 3.4756153510784327e-15
# Validation Loss: 30.42372789300275
# Training completed.
# Test score with FFNN: 0.1191

# %%
model4.save("model4.pkl")

# %%
model5 = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model5.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model5.fit(X_train, y_train, X_test, y_test)
y_pred = model5.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Epoch 1, Training Loss: 0.0015053450886357035
# Validation Loss: 30.05120251902906
# Epoch 2, Training Loss: 0.0001353012770734984
# Validation Loss: 30.036400186288386
# Epoch 3, Training Loss: 7.904964916671348e-05
# Validation Loss: 30.03393313083161
# Epoch 4, Training Loss: 5.607429965885566e-05
# Validation Loss: 30.04626840811551
# Epoch 5, Training Loss: 4.3456339275108454e-05
# Validation Loss: 30.04873546357229
# Epoch 6, Training Loss: 3.548289722305304e-05
# Validation Loss: 30.03640018628839
# Epoch 7, Training Loss: 2.9986120704899933e-05
# Validation Loss: 30.024064909004494
# Epoch 8, Training Loss: 2.5967777986186392e-05
# Validation Loss: 30.033933130831606
# Epoch 9, Training Loss: 2.2893872827203433e-05
# Validation Loss: 30.02406490900449
# Epoch 10, Training Loss: 2.047252594739044e-05
# Validation Loss: 30.02159785354771
# Training completed.
# Test score with FFNN: 0.1308

# %%
model5.save("model5.pkl")

# %%
sigmoid = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["sigmoid", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
sigmoid.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

sigmoid.fit(X_train, y_train, X_test, y_test)
y_pred = sigmoid.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
sigmoid.save("sigmoid.pkl")
# Out:
# Epoch 1, Training Loss: 0.0015255638738948002
# Validation Loss: 30.41632672663241
# Epoch 2, Training Loss: 0.00013824504309341155
# Validation Loss: 30.42126083754597
# Epoch 3, Training Loss: 8.082169286479816e-05
# Validation Loss: 30.42126083754597
# Epoch 4, Training Loss: 5.7327473474965826e-05
# Validation Loss: 30.436063170286644
# Epoch 5, Training Loss: 4.4458872724952656e-05
# Validation Loss: 30.431129059373085
# Epoch 6, Training Loss: 3.632115388565471e-05
# Validation Loss: 30.438530225743424
# Epoch 7, Training Loss: 3.0705934768026356e-05
# Validation Loss: 30.44593139211376
# Epoch 8, Training Loss: 2.6596491249096622e-05
# Validation Loss: 30.45086550302732
# Epoch 9, Training Loss: 2.3458223870191822e-05
# Validation Loss: 30.463200780311215
# Epoch 10, Training Loss: 2.098284218138923e-05
# Validation Loss: 30.468134891224775
# Training completed.
# Test score with FFNN: 0.1179

# %%
linear = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["linear", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
linear.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

linear.fit(X_train, y_train, X_test, y_test)
y_pred = linear.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
linear.save("linear.pkl")
# Out:
# d:\Github\Tugas-Machine-Learning-1\src\FFNN.py:28: RuntimeWarning: overflow encountered in exp
#   self.output = 1 / (1 + np.exp(-z))
# Epoch 1, Training Loss: 19.001201928959897
# Validation Loss: 31.299532580159408
# Epoch 2, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 3, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 4, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 5, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 6, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 7, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 8, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 9, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Epoch 10, Training Loss: 19.000471670368498
# Validation Loss: 31.299532580159408
# Training completed.
# Test score with FFNN: 0.0938

# %%
tanh = FFNN(
    layers=[X_train.shape[1], 15, 10],
    activation_functions=["tanh", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
tanh.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

tanh.fit(X_train, y_train, X_test, y_test)
y_pred = tanh.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
tanh.save("tanh.pkl")
# Out:
# Epoch 1, Training Loss: 12.880853610532512
# Validation Loss: 31.450022963022946
# Epoch 2, Training Loss: 15.893482305069323
# Validation Loss: 31.450022963022946
# Epoch 3, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 4, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 5, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 6, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 7, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 8, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 9, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Epoch 10, Training Loss: 16.032900002517735
# Validation Loss: 31.450022963022946
# Training completed.
# Test score with FFNN: 0.0894

# %%
model6 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.01, epoch=10, verbose=1, 
    batch_size=1
)
model6.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model6.fit(X_train, y_train, X_test, y_test)
y_pred = model6.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model6.save("model6.pkl")
# Out:
# Epoch 1, Training Loss: 0.00020872004549068053
# Validation Loss: 29.501049152167273
# Epoch 2, Training Loss: 2.1717432856908597e-05
# Validation Loss: 29.496115041253713
# Epoch 3, Training Loss: 1.212098806514101e-05
# Validation Loss: 29.493647985796933
# Epoch 4, Training Loss: 8.3517634931201e-06
# Validation Loss: 29.481312708513038
# Epoch 5, Training Loss: 6.340666916157631e-06
# Validation Loss: 29.483779763969817
# Epoch 6, Training Loss: 5.094142404086941e-06
# Validation Loss: 29.476378597599478
# Epoch 7, Training Loss: 4.247677290011308e-06
# Validation Loss: 29.483779763969817
# Epoch 8, Training Loss: 3.6364685180387642e-06
# Validation Loss: 29.481312708513038
# Epoch 9, Training Loss: 3.1754114510775546e-06
# Validation Loss: 29.491180930340157
# Epoch 10, Training Loss: 2.8147844225882345e-06
# Validation Loss: 29.488713874883377
# Training completed.
# Test score with FFNN: 0.1462

# %%
model7 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.001, epoch=10, verbose=1, 
    batch_size=1
)
model7.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model7.fit(X_train, y_train, X_test, y_test)
y_pred = model7.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model7.save("model7.pkl")
# Out:
# Epoch 1, Training Loss: 0.0012699108364294701
# Validation Loss: 29.505983263080832
# Epoch 2, Training Loss: 0.0002588009422821795
# Validation Loss: 29.503516207624052
# Epoch 3, Training Loss: 0.00014657219045125942
# Validation Loss: 29.501049152167273
# Epoch 4, Training Loss: 0.00010140343679285702
# Validation Loss: 29.501049152167273
# Epoch 5, Training Loss: 7.708427736180687e-05
# Validation Loss: 29.503516207624052
# Epoch 6, Training Loss: 6.194897030895017e-05
# Validation Loss: 29.501049152167273
# Epoch 7, Training Loss: 5.164549319196132e-05
# Validation Loss: 29.503516207624052
# Epoch 8, Training Loss: 4.4196316744706535e-05
# Validation Loss: 29.503516207624052
# Epoch 9, Training Loss: 3.857599322734629e-05
# Validation Loss: 29.503516207624052
# Epoch 10, Training Loss: 3.417450245610295e-05
# Validation Loss: 29.501049152167273
# Training completed.
# Test score with FFNN: 0.1459

# %%
model8 = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.0001, epoch=10, verbose=1, 
    batch_size=1
)
model8.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model8.fit(X_train, y_train, X_test, y_test)
y_pred = model8.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model8.save("model8.pkl")
# Out:
# Epoch 1, Training Loss: 0.004476819940449838
# Validation Loss: 29.508450318537612
# Epoch 2, Training Loss: 0.002204499770409349
# Validation Loss: 29.503516207624052
# Epoch 3, Training Loss: 0.0014469584287532524
# Validation Loss: 29.503516207624052
# Epoch 4, Training Loss: 0.0010688851847229827
# Validation Loss: 29.498582096710493
# Epoch 5, Training Loss: 0.0008432230019779984
# Validation Loss: 29.501049152167273
# Epoch 6, Training Loss: 0.0006939411393088875
# Validation Loss: 29.503516207624052
# Epoch 7, Training Loss: 0.0005880698639742304
# Validation Loss: 29.501049152167273
# Epoch 8, Training Loss: 0.0005092756148639732
# Validation Loss: 29.503516207624052
# Epoch 9, Training Loss: 0.0004485486930613255
# Validation Loss: 29.503516207624052
# Epoch 10, Training Loss: 0.00040015486704347787
# Validation Loss: 29.510917373994392
# Training completed.
# Test score with FFNN: 0.1456

# %%
model9batch = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.01, epoch=10, verbose=1, 
    batch_size=200
)
model8.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)
model8.fit(X_train, y_train, X_test, y_test)
y_pred = model8.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# model8.save("model8.pkl")
# Out:
# Epoch 1, Training Loss: 0.004469487480201615
# Validation Loss: 29.508450318537612
# Epoch 2, Training Loss: 0.0022049336980994923
# Validation Loss: 29.503516207624052
# Epoch 3, Training Loss: 0.0014474929660283898
# Validation Loss: 29.503516207624052
# Epoch 4, Training Loss: 0.0010687497694792701
# Validation Loss: 29.498582096710493
# Epoch 5, Training Loss: 0.0008431451638900326
# Validation Loss: 29.501049152167273
# Epoch 6, Training Loss: 0.0006939142196334794
# Validation Loss: 29.505983263080832
# Epoch 7, Training Loss: 0.0005880098106227807
# Validation Loss: 29.501049152167273
# Epoch 8, Training Loss: 0.0005092915964873407
# Validation Loss: 29.501049152167273
# Epoch 9, Training Loss: 0.00044848421002256593
# Validation Loss: 29.503516207624052
# Epoch 10, Training Loss: 0.00040017095459148484
# Validation Loss: 29.510917373994392
# Training completed.
# Test score with FFNN: 0.1456

# %%
model_zero = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_zero.weight_initializer(weight_initializer="zero")

model_zero.fit(X_train, y_train, X_test, y_test)
y_pred = model_zero.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_zero.save("model_zero.pkl")
# Out:
# Epoch 1, Training Loss: 0.001791494062040147
# Validation Loss: 31.235389138283146
# Epoch 2, Training Loss: 0.00013876889899194428
# Validation Loss: 31.235389138283146
# Epoch 3, Training Loss: 8.114313924993235e-05
# Validation Loss: 31.235389138283146
# Epoch 4, Training Loss: 5.756258915445188e-05
# Validation Loss: 31.235389138283146
# Epoch 5, Training Loss: 4.464490446739748e-05
# Validation Loss: 31.235389138283146
# Epoch 6, Training Loss: 3.6475365550999056e-05
# Validation Loss: 31.235389138283146
# Epoch 7, Training Loss: 3.083818449593602e-05
# Validation Loss: 31.235389138283146
# Epoch 8, Training Loss: 2.671241272305838e-05
# Validation Loss: 31.235389138283146
# Epoch 9, Training Loss: 2.3561444580997332e-05
# Validation Loss: 31.235389138283146
# Epoch 10, Training Loss: 2.1076020241151934e-05
# Validation Loss: 31.235389138283146
# Training completed.
# Test score with FFNN: 0.0956

# %%
model_uniform = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_uniform.weight_initializer(weight_initializer="uniform")
model_uniform.fit(X_train, y_train, X_test, y_test)
y_pred = model_uniform.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_uniform.save("model_uniform.pkl")
# Out:
# d:\Github\Tugas-Machine-Learning-1\src\FFNN.py:28: RuntimeWarning: overflow encountered in exp
#   self.output = 1 / (1 + np.exp(-z))
# Epoch 1, Training Loss: 3.8745599359811274
# Validation Loss: 31.16631158549333
# Epoch 2, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 3, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 4, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 5, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 6, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 7, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 8, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 9, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Epoch 10, Training Loss: 3.873869160453229
# Validation Loss: 31.16631158549333
# Training completed.
# Test score with FFNN: 0.0976

# %%
model_sklearn_compare = FFNN(
    layers=[X_train.shape[1], 15, 15, 10],
    activation_functions=["relu", "relu", "sigmoid"],
    loss_function="categorical_cross_entropy",
    random_state=42, learning_rate=0.1, epoch=10, verbose=1, 
    batch_size=1
)
model_sklearn_compare.weight_initializer(weight_initializer="normal", mean=0.5, variance=0.1)

model_sklearn_compare.fit(X_train, y_train, X_test, y_test)
y_pred = model_sklearn_compare.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_sklearn_compare.save("model_sklearn_compare.pkl")
# Out:
# Epoch 1, Training Loss: 2.7240816801607193e-05
# Validation Loss: 29.431971599377455
# Epoch 2, Training Loss: 1.7963960544455482e-06
# Validation Loss: 29.431971599377455
# Epoch 3, Training Loss: 1.0068076759995385e-06
# Validation Loss: 29.429504543920675
# Epoch 4, Training Loss: 6.9593727997786e-07
# Validation Loss: 29.429504543920675
# Epoch 5, Training Loss: 5.296711813929737e-07
# Validation Loss: 29.427037488463895
# Epoch 6, Training Loss: 4.264319763709271e-07
# Validation Loss: 29.41963632209356
# Epoch 7, Training Loss: 3.5619820232036434e-07
# Validation Loss: 29.41963632209356
# Epoch 8, Training Loss: 3.0538016124728883e-07
# Validation Loss: 29.41470221118
# Epoch 9, Training Loss: 2.6697775767188886e-07
# Validation Loss: 29.41223515572322
# Epoch 10, Training Loss: 2.369434814323331e-07
# Validation Loss: 29.41223515572322
# Training completed.
# Test score with FFNN: 0.1484

# %%
model_sklearn = MLPClassifier(
    hidden_layer_sizes=(15, 15),  
    activation='relu', 
    learning_rate_init=0.1,  
    max_iter=10, 
    batch_size=1, 
    random_state=42,
)
model_sklearn.fit(X_train, y_train)
y_pred = model_sklearn.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with sklearn MLPClassifier: %.4f" % score)
# Out:
# Test score with sklearn MLPClassifier: 0.0944
# c:\Users\LEGION\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import pickle


with open("mlp_model.pkl", "wb") as f:
    pickle.dump(model_sklearn, f)
