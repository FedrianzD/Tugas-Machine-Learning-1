# %%
from FFNN import FFNN
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state

# %%
t0 = time.time()
train_samples = 50000

# %%
X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)

# %%
random_state = check_random_state(0)
permutation = random_state.permutation(X.shape[0])
X = X[permutation]
y = y[permutation]
X = X.reshape((X.shape[0], -1))

# %%
print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=train_samples, test_size=0.2
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = FFNN.load("model.pkl")
y_pred = model.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Test score with FFNN: 0.1031

# %%
model.visualize_weight_distributions([0,1,2], "model1")

# %%
model.visualize_weight_gradient_distributions([0,1,2], "model1")

# %%
model.visualize_validation_loss("model1")

# %%
model.visualize_train_loss("model1")

# %%
model2 = FFNN.load("model2.pkl")
y_pred = model2.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Test score with FFNN: 0.1533

# %%
model2.visualize_train_loss("model2")

# %%
model2.visualize_validation_loss("model2")

# %%
model2.visualize_weight_distributions([0,1], "model2")
model2.visualize_weight_gradient_distributions([0,1], "model2")

# %%
model3 = FFNN.load("model3.pkl")
y_pred = model3.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
# Out:
# Test score with FFNN: 0.1254

# %%
model3.visualize_train_loss("model3")
model3.visualize_validation_loss("model3")

# %%
model4 = FFNN.load("model4.pkl")
y_pred = model4.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model4.visualize_train_loss("model4")
model4.visualize_validation_loss("model4")
# Out:
# Test score with FFNN: 0.1244

# %%
model5 = FFNN.load("model5.pkl")
y_pred = model5.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model5.visualize_train_loss("model5")
model5.visualize_validation_loss("model5")
# Out:
# Test score with FFNN: 0.1359

# %%
model5.visualize_weight_distributions([0], "model5 relu")
model5.visualize_weight_gradient_distributions([0], "model5 relu")

# %%
linear = FFNN.load("linear.pkl")
y_pred = linear.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
linear.visualize_train_loss("linear")
linear.visualize_validation_loss("linear")
linear.visualize_weight_distributions([0], "linear")
linear.visualize_weight_gradient_distributions([0], "linear")
# Out:
# d:\Github\Tugas-Machine-Learning-1\src\FFNN.py:28: RuntimeWarning: overflow encountered in exp
#   self.output = 1 / (1 + np.exp(-z))
# Test score with FFNN: 0.0969

# %%
sigmoid = FFNN.load("sigmoid.pkl")
y_pred = sigmoid.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
sigmoid.visualize_train_loss("sigmoid")
sigmoid.visualize_validation_loss("sigmoid")
sigmoid.visualize_weight_distributions([0], "sigmoid")
sigmoid.visualize_weight_gradient_distributions([0], "sigmoid")
# Out:
# Test score with FFNN: 0.1136

# %%
tanh = FFNN.load("tanh.pkl")
y_pred = tanh.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
tanh.visualize_train_loss("tanh")
tanh.visualize_validation_loss("tanh")
tanh.visualize_weight_distributions([0], "tanh")
tanh.visualize_weight_gradient_distributions([0], "tanh")
# Out:
# d:\Github\Tugas-Machine-Learning-1\src\FFNN.py:28: RuntimeWarning: overflow encountered in exp
#   self.output = 1 / (1 + np.exp(-z))
# Test score with FFNN: 0.0956

# %%
model6 = FFNN.load("model6.pkl")
y_pred = model6.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model6.visualize_train_loss("model6")
model6.visualize_validation_loss("model6")
model6.visualize_weight_distributions([0,1], "model6")
model6.visualize_weight_gradient_distributions([0,1], "model6")
# Out:
# Test score with FFNN: 0.1531

# %%
model7 = FFNN.load("model7.pkl")
y_pred = model7.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model7.visualize_train_loss("model7")
model7.visualize_validation_loss("model7")
model7.visualize_weight_distributions([0,1], "model7")
model7.visualize_weight_gradient_distributions([0,1], "model7")
# Out:
# Test score with FFNN: 0.1529

# %%
model8 = FFNN.load("model8.pkl")
y_pred = model8.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model8.visualize_train_loss("model8")
model8.visualize_validation_loss("model8")
model8.visualize_weight_distributions([0,1], "model8")
model8.visualize_weight_gradient_distributions([0,1], "model8")
# Out:
# Test score with FFNN: 0.1527

# %%
model2sigmoid = FFNN.load("model2sigmoid.pkl")
y_pred = model2sigmoid.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model2sigmoid.visualize_train_loss("model2sigmoid")
model2sigmoid.visualize_validation_loss("model2sigmoid")
model2sigmoid.visualize_weight_distributions([0,1], "model2sigmoid")
model2sigmoid.visualize_weight_gradient_distributions([0,1], "model2sigmoid")
# Out:
# Test score with FFNN: 0.1522

# %%
model_zero = FFNN.load("model_zero.pkl")
y_pred = model_zero.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_zero.visualize_train_loss("model_zero")
model_zero.visualize_validation_loss("model_zero")
model_zero.visualize_weight_distributions([0,1], "model_zero")
model_zero.visualize_weight_gradient_distributions([0,1], "model_zero")

# %%
model_uniform = FFNN.load("model_uniform.pkl")
y_pred = model_uniform.predict(X_test)
score = np.mean(y_pred == y_test)
print("Test score with FFNN: %.4f" % score)
model_uniform.visualize_train_loss("model_uniform")
model_uniform.visualize_validation_loss("model_uniform")
model_uniform.visualize_weight_distributions([0,1], "model_uniform")
model_uniform.visualize_weight_gradient_distributions([0,1], "model_uniform")
